# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
from datetime import datetime
import numpy as np

driver = webdriver.Firefox(executable_path=r'D:\downloads\geckodriver\geckodriver.exe')
driver.implicitly_wait(10)

def get_fights():
    # Define columns and initialize empty dataframe
    fight_columns = ['Date', 'Fighter1', 'Fighter2','Result', 'Event', 'Location', 'Attendance', 'Weightclass',
                     'Details', 'Judge1', 'Judge2', 'Judge3', 'Judge1_Fighter1_Score', 'Judge1_Fighter2_Score',
                     'Judge2_Fighter1_Score', 'Judge2_Fighter2_Score', 'Judge3_Fighter1_Score', 'Judge3_Fighter2_Score']
    fights = pd.DataFrame(columns=fight_columns)
    
    # Startup Selenium and nagivate to events page
    url = 'http://ufcstats.com/statistics/events/completed?page=all'
    driver.get(url)
    
    # Get a list of links to all events
    events_page = BeautifulSoup(driver.page_source, 'lxml')
    events_table = events_page.find('table', {'class':'b-statistics__table-events'})
    events_links = events_table.find_all('a')
    events_urls = [link.get('href') for link in events_links[1::]]

    # Loop through all events
    for event_url in events_urls[::-1][0::]:
        driver.get(event_url)
        fights_page = BeautifulSoup(driver.page_source, 'lxml')
        
        # Get Basic Event Information
        event_details_html = fights_page.find_all('li', 'b-list__box-list-item')
        event_details = {}
        
        event_title = fights_page.find('span', 'b-content__title-highlight').get_text(strip=True)

        for event_detail in event_details_html:
            text = event_detail.contents[1].get_text(strip=True)
            if text == 'Date:':
                date = datetime.strptime(event_detail.get_text(strip=True).split(':')[1], '%B %d, %Y')
            elif text == 'Location:':
                location = event_detail.get_text(strip=True).split(':')[1]
            elif text == 'Attendance:':
                attendance = event_detail.get_text(strip=True).split(':')[1]
        
        # Get list of links to all fights in event
        fights_table = fights_page.find('table', {'class':'b-fight-details__table'})
        fights_table_rows = fights_table.find_all('tr', 'b-fight-details__table-row')
        fights_urls = [row.get('data-link') for row in fights_table_rows[1::]]
        
        # Loop through all fights in event
        for fight_url in fights_urls[::-1][0::]:
            fight_row = pd.DataFrame(columns=fight_columns)
            
            driver.get(fight_url)
            
            fight_stats_page = BeautifulSoup(driver.page_source, 'lxml')
            
            # Get fighters in fight
            fighters_spans = fight_stats_page.find_all('h3', 'b-fight-details__person-name')
            fighters = [span.get_text(strip=True) for span in fighters_spans]
            
            # Get result of fight (win / draw)
            results_html = fight_stats_page.find_all('i', 'b-fight-details__person-status')
            results = [element.get_text(strip=True) for element in results_html]
            if 'D' in results:
                result = 'Draw'
            else:
                result = 'Win'
                
            # Get weight lcass
            weight_class_details_text = fight_stats_page.find('i', 'b-fight-details__fight-title').get_text(strip=True)
            weight_class_details_text_list = weight_class_details_text.split(' ')
            for i in range(len(weight_class_details_text_list)):
                # For all weight classes except 'Open'    
                if 'weight' in weight_class_details_text_list[i]:
                    weight_class = weight_class_details_text_list[i]
                else:
                    weight_class = 'Open Weight'
                    
            fight_info = {'Date':date, 'Fighter1':fighters[0], 'Fighter2':fighters[1],'Result':result,
                          'Event':event_title, 'Location':location, 'Attendance':attendance, 'Weightclass':weight_class}
            
            # Get Fight Details
            fight_details_html = fight_stats_page.find_all('i', ['b-fight-details__text-item', 'b-fight-details__text-item_first'])
            fight_details_list = [element for element in fight_details_html]
            
            # Get Fight Details_Details and Judges/Scores
            details = fight_details_list[-1].parent.get_text(' ', strip=True).split(':')
            if '.' in details[1]:
                details = details[1::][0].split('.')[0:-1]
                details = [detail[1::].split(' ') for detail in details]
                
                for i in range(0,3):
                    for j in range(1,3): 
                        fight_info[f'Judge{i+1}'] = ' '.join(details[i][0:-3])
                        fight_info[f'Judge{i+1}_Fighter{j}_Score'] = details[i][-3::][j-1]
            else:
                fight_info['Details'] = details[1][1::]
                        
            fight_details_list = [element.get_text(strip=True).split(':') for element in fight_details_html]
            for fight_detail in fight_details_list:
                if fight_detail[0] == 'Round':
                    fight_info['Round_End'] = fight_detail[1]
                elif fight_detail[0] == 'Time':
                    fight_info['Round_Time'] = (int(fight_detail[1]) * 60) + int(fight_detail[2])
                elif fight_detail[0] == 'Time format':
                    fight_info['Time Format'] = fight_detail[1]
                elif fight_detail[0] == 'Referee':
                    fight_info['Referee'] = fight_detail[1]
                elif fight_detail[0] == 'Method':
                    fight_info['Method'] = fight_detail[1]
                    
            fight_stats_row_html_list_all_rows = fight_stats_page.find_all('tr', 'b-fight-details__table-row')
            fight_stats_total_end = int(len(fight_stats_row_html_list_all_rows)-(len(fight_stats_row_html_list_all_rows)/2))
            
            fight_stats_total_row_html_list = fight_stats_row_html_list_all_rows[3:fight_stats_total_end]
            fight_stats_sig_row_html_list = fight_stats_row_html_list_all_rows[fight_stats_total_end+3::]
            
            # Round Total Stats
            total_stats = []
            for i in range(len(fight_stats_total_row_html_list)):
                round_stats_total_text_html = fight_stats_total_row_html_list[i].find_all('p', 'b-fight-details__table-text')
                round_stats_total_list = [element.get_text(strip=True) for element in round_stats_total_text_html[2::]]
                
                round_total_stats = {}
                
                for j in range(1,3):
                    round_total_stats[f'Fighter{j}_Knock_Downs_Round{i+1}'] = round_stats_total_list[j-1]
                    round_total_stats[f'Fighter{j}_Sig_Strikes_Round{i+1}'] = round_stats_total_list[j+1].split(' ')[0]
                    round_total_stats[f'Fighter{j}_Sig_Strikes_Attempted_Round{i+1}'] = round_stats_total_list[j+1].split(' ')[-1]
                    round_total_stats[f'Fighter{j}_Total_Strikes_Round{i+1}'] = round_stats_total_list[j+5].split(' ')[0]
                    round_total_stats[f'Fighter{j}_Total_Strikes_Attempted_Round{i+1}'] = round_stats_total_list[j+5].split(' ')[-1]
                    round_total_stats[f'Fighter{j}_Take_Downs_Round{i+1}'] = round_stats_total_list[j+7].split(' ')[0]
                    round_total_stats[f'Fighter{j}_Take_Downs_Attempted_Round{i+1}'] = round_stats_total_list[j+7].split(' ')[-1]
                    round_total_stats[f'Fighter{j}_Submission_Attempts_Round{i+1}'] = round_stats_total_list[j+11]
                    round_total_stats[f'Fighter{j}_Reversals_Round{i+1}'] = round_stats_total_list[j+13]  
                    
                total_stats.append(round_total_stats)
              
            total_stats_combined = {}
            for round_dict in total_stats:
                total_stats_combined.update(round_dict)
                
            # Round Significant Strikes Stats
            sig_stats = []
            for i in range(len(fight_stats_sig_row_html_list)):
                round_stats_sig_text_html = fight_stats_sig_row_html_list[i].find_all('p', 'b-fight-details__table-text')
                round_stats_sig_list = [element.get_text(strip=True) for element in round_stats_sig_text_html[2::]]
            
                round_sig_stats = {}
                
                for j in range(1,3):
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Head_Round{i+1}'] = round_stats_sig_list[j+3].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Head_Attempted_Round{i+1}'] = round_stats_sig_list[j+3].split(' ')[-1]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Body_Round{i+1}'] = round_stats_sig_list[j+5].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Body_Attempted_Round{i+1}'] = round_stats_sig_list[j+5].split(' ')[-1]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Leg_Round{i+1}'] = round_stats_sig_list[j+7].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Leg_Attempted_Round{i+1}'] = round_stats_sig_list[j+7].split(' ')[-1]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Distance_Round{i+1}'] = round_stats_sig_list[j+9].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Distance_Attempted_Round{i+1}'] = round_stats_sig_list[j+9].split(' ')[-1]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Clinch_Round{i+1}'] = round_stats_sig_list[j+11].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Clinch_Attempted_Round{i+1}'] = round_stats_sig_list[j+11].split(' ')[-1]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Ground_Round{i+1}'] = round_stats_sig_list[j+13].split(' ')[0]
                    round_sig_stats[f'Fighter{j}_Sig_Strikes_Ground_Attempted_Round{i+1}'] = round_stats_sig_list[j+13].split(' ')[-1]
            
                sig_stats.append(round_sig_stats)
            
            sig_stats_combined = {}
            for round_dict in sig_stats:
                sig_stats_combined.update(round_dict)
            
            
            # Combine all the different dictionaries into one and add is as a row to dataframe
            stats = {}
            for stats_dict in (total_stats_combined, sig_stats_combined):
                stats.update(stats_dict)
                
            fight = {}
            for d in (fight_info, stats):
                fight.update(d)
            
            fights = fights.append(fight, ignore_index=True)
    return fights
        
fights = get_fights()
fights
# Out:
#            Date               Fighter1             Fighter2 Result  \
# 0    1993-11-12         Gerard Gordeau           Teila Tuli    Win
# 1    1993-11-12           Kevin Rosier         Zane Frazier    Win
# 2    1993-11-12           Royce Gracie        Art Jimmerson    Win
# 3    1993-11-12           Ken Shamrock        Patrick Smith    Win
# 4    1993-11-12         Gerard Gordeau         Kevin Rosier    Win
# 5    1993-11-12           Royce Gracie         Ken Shamrock    Win
# 6    1993-11-12          Jason DeLucia        Trent Jenkins    Win
# 7    1993-11-12           Royce Gracie       Gerard Gordeau    Win
# 8    1994-03-11           Scott Morris       Sean Daugherty    Win
# 9    1994-03-11          Patrick Smith           Ray Wizard    Win
# 10   1994-03-11          Johnny Rhodes        David Levicki    Win
# 11   1994-03-11          Frank Hamaker      Thaddeus Luster    Win
# 12   1994-03-11           Orlando Wiet     Robert Lucarelli    Win
# 13   1994-03-11          Remco Pardoel   Alberta Cerra Leon    Win
# 14   1994-03-11          Jason DeLucia          Scott Baker    Win
# 15   1994-03-11           Royce Gracie      Minoki Ichihara    Win
# 16   1994-03-11          Patrick Smith         Scott Morris    Win
# 17   1994-03-11          Johnny Rhodes          Fred Ettish    Win
# 18   1994-03-11          Remco Pardoel         Orlando Wiet    Win
# 19   1994-03-11           Royce Gracie        Jason DeLucia    Win
# 20   1994-03-11          Patrick Smith        Johnny Rhodes    Win
# 21   1994-03-11           Royce Gracie        Remco Pardoel    Win
# 22   1994-03-11           Royce Gracie        Patrick Smith    Win
# 23   1994-09-09          Keith Hackney  Emmanuel Yarborough    Win
# 24   1994-09-09           Ken Shamrock  Christophe Leninger    Win
# 25   1994-09-09          Harold Howard         Roland Payne    Win
# 26   1994-09-09           Royce Gracie        Kimo Leopoldo    Win
# 27   1994-09-09           Ken Shamrock   Felix Lee Mitchell    Win
# 28   1994-09-09           Steve Jennum        Harold Howard    Win
# 29   1994-12-16            Joe Charles         Kevin Rosier    Win
# ...         ...                    ...                  ...    ...
# 5071 2019-03-30           Sodiq Yusuff       Sheymon Moraes    Win
# 5072 2019-03-30      Kennedy Nzechukwu           Paul Craig    Win
# 5073 2019-03-30  Karolina Kowalkiewicz    Michelle Waterson    Win
# 5074 2019-03-30            Josh Emmett      Michael Johnson    Win
# 5075 2019-03-30           David Branch      Jack Hermansson    Win
# 5076 2019-03-30          Edson Barboza       Justin Gaethje    Win
# 5077 2019-04-13          Brandon Davis          Randy Costa    Win
# 5078 2019-04-13         Lauren Mueller      Poliana Botelho    Win
# 5079 2019-04-13         Montel Jackson   Andre Soukhamthath    Win
# 5080 2019-04-13       Curtis Millender       Belal Muhammad    Win
# 5081 2019-04-13          Boston Salmon          Khalid Taha    Win
# 5082 2019-04-13            Max Griffin        Zelim Imadaev    Win
# 5083 2019-04-13            Wilson Reis    Alexandre Pantoja    Win
# 5084 2019-04-13           Jalin Turner         Matt Frevola    Win
# 5085 2019-04-13     Ovince Saint Preux        Nikita Krylov    Win
# 5086 2019-04-13            Alan Jouban         Dwight Grant    Win
# 5087 2019-04-13            Eryk Anders  Khalil Rountree Jr.    Win
# 5088 2019-04-13        Kelvin Gastelum      Israel Adesanya    Win
# 5089 2019-04-13           Max Holloway       Dustin Poirier    Win
# 5090 2019-04-20      Magomed Mustafaev        Rafael Fiziev    Win
# 5091 2019-04-20  Gadzhimurad Antigulov  Michal Oleksiejczuk    Win
# 5092 2019-04-20          Marcin Tybura  Shamil Abdurakhimov    Win
# 5093 2019-04-20     Alexander Yakovlev        Alex Da Silva    Win
# 5094 2019-04-20           Sultan Aliev       Keita Nakamura    Win
# 5095 2019-04-20          Movsar Evloev        Seungwoo Choi    Win
# 5096 2019-04-20        Krzysztof Jotko       Alen Amedovski    Win
# 5097 2019-04-20      Roxanne Modafferi  Antonina Shevchenko    Win
# 5098 2019-04-20       Sergei Pavlovich         Marcelo Golm    Win
# 5099 2019-04-20        Islam Makhachev      Arman Tsarukyan    Win
# 5100 2019-04-20       Alistair Overeem      Aleksei Oleinik    Win
#
#                                      Event  \
# 0                     UFC 1: The Beginning
# 1                     UFC 1: The Beginning
# 2                     UFC 1: The Beginning
# 3                     UFC 1: The Beginning
# 4                     UFC 1: The Beginning
# 5                     UFC 1: The Beginning
# 6                     UFC 1: The Beginning
# 7                     UFC 1: The Beginning
# 8                        UFC 2: No Way Out
# 9                        UFC 2: No Way Out
# 10                       UFC 2: No Way Out
# 11                       UFC 2: No Way Out
# 12                       UFC 2: No Way Out
# 13                       UFC 2: No Way Out
# 14                       UFC 2: No Way Out
# 15                       UFC 2: No Way Out
# 16                       UFC 2: No Way Out
# 17                       UFC 2: No Way Out
# 18                       UFC 2: No Way Out
# 19                       UFC 2: No Way Out
# 20                       UFC 2: No Way Out
# 21                       UFC 2: No Way Out
# 22                       UFC 2: No Way Out
# 23               UFC 3: The American Dream
# 24               UFC 3: The American Dream
# 25               UFC 3: The American Dream
# 26               UFC 3: The American Dream
# 27               UFC 3: The American Dream
# 28               UFC 3: The American Dream
# 29          UFC 4: Revenge of the Warriors
# ...                                    ...
# 5071  UFC Fight Night: Barboza vs. Gaethje
# 5072  UFC Fight Night: Barboza vs. Gaethje
# 5073  UFC Fight Night: Barboza vs. Gaethje
# 5074  UFC Fight Night: Barboza vs. Gaethje
# 5075  UFC Fight Night: Barboza vs. Gaethje
# 5076  UFC Fight Night: Barboza vs. Gaethje
# 5077       UFC 236: Holloway vs. Poirier 2
# 5078       UFC 236: Holloway vs. Poirier 2
# 5079       UFC 236: Holloway vs. Poirier 2
# 5080       UFC 236: Holloway vs. Poirier 2
# 5081       UFC 236: Holloway vs. Poirier 2
# 5082       UFC 236: Holloway vs. Poirier 2
# 5083       UFC 236: Holloway vs. Poirier 2
# 5084       UFC 236: Holloway vs. Poirier 2
# 5085       UFC 236: Holloway vs. Poirier 2
# 5086       UFC 236: Holloway vs. Poirier 2
# 5087       UFC 236: Holloway vs. Poirier 2
# 5088       UFC 236: Holloway vs. Poirier 2
# 5089       UFC 236: Holloway vs. Poirier 2
# 5090  UFC Fight Night: Overeem vs. Oleinik
# 5091  UFC Fight Night: Overeem vs. Oleinik
# 5092  UFC Fight Night: Overeem vs. Oleinik
# 5093  UFC Fight Night: Overeem vs. Oleinik
# 5094  UFC Fight Night: Overeem vs. Oleinik
# 5095  UFC Fight Night: Overeem vs. Oleinik
# 5096  UFC Fight Night: Overeem vs. Oleinik
# 5097  UFC Fight Night: Overeem vs. Oleinik
# 5098  UFC Fight Night: Overeem vs. Oleinik
# 5099  UFC Fight Night: Overeem vs. Oleinik
# 5100  UFC Fight Night: Overeem vs. Oleinik
#
#                                         Location Attendance  Weightclass  \
# 0                          Denver, Colorado, USA      2,800  Open Weight
# 1                          Denver, Colorado, USA      2,800  Open Weight
# 2                          Denver, Colorado, USA      2,800  Open Weight
# 3                          Denver, Colorado, USA      2,800  Open Weight
# 4                          Denver, Colorado, USA      2,800  Open Weight
# 5                          Denver, Colorado, USA      2,800  Open Weight
# 6                          Denver, Colorado, USA      2,800  Open Weight
# 7                          Denver, Colorado, USA      2,800  Open Weight
# 8                          Denver, Colorado, USA      2,000  Open Weight
# 9                          Denver, Colorado, USA      2,000  Open Weight
# 10                         Denver, Colorado, USA      2,000  Open Weight
# 11                         Denver, Colorado, USA      2,000  Open Weight
# 12                         Denver, Colorado, USA      2,000  Open Weight
# 13                         Denver, Colorado, USA      2,000  Open Weight
# 14                         Denver, Colorado, USA      2,000  Open Weight
# 15                         Denver, Colorado, USA      2,000  Open Weight
# 16                         Denver, Colorado, USA      2,000  Open Weight
# 17                         Denver, Colorado, USA      2,000  Open Weight
# 18                         Denver, Colorado, USA      2,000  Open Weight
# 19                         Denver, Colorado, USA      2,000  Open Weight
# 20                         Denver, Colorado, USA      2,000  Open Weight
# 21                         Denver, Colorado, USA      2,000  Open Weight
# 22                         Denver, Colorado, USA      2,000  Open Weight
# 23                Charlotte, North Carolina, USA             Open Weight
# 24                Charlotte, North Carolina, USA             Open Weight
# 25                Charlotte, North Carolina, USA             Open Weight
# 26                Charlotte, North Carolina, USA             Open Weight
# 27                Charlotte, North Carolina, USA             Open Weight
# 28                Charlotte, North Carolina, USA             Open Weight
# 29                          Tulsa, Oklahoma, USA      5,857  Open Weight
# ...                                          ...        ...          ...
# 5071             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5072             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5073             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5074             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5075             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5076             Philadelphia, Pennsylvania, USA     11,123  Open Weight
# 5077                       Atlanta, Georgia, USA     14,297  Open Weight
# 5078                       Atlanta, Georgia, USA     14,297  Open Weight
# 5079                       Atlanta, Georgia, USA     14,297  Open Weight
# 5080                       Atlanta, Georgia, USA     14,297  Open Weight
# 5081                       Atlanta, Georgia, USA     14,297  Open Weight
# 5082                       Atlanta, Georgia, USA     14,297  Open Weight
# 5083                       Atlanta, Georgia, USA     14,297  Open Weight
# 5084                       Atlanta, Georgia, USA     14,297  Open Weight
# 5085                       Atlanta, Georgia, USA     14,297  Open Weight
# 5086                       Atlanta, Georgia, USA     14,297  Open Weight
# 5087                       Atlanta, Georgia, USA     14,297  Open Weight
# 5088                       Atlanta, Georgia, USA     14,297  Open Weight
# 5089                       Atlanta, Georgia, USA     14,297  Open Weight
# 5090  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5091  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5092  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5093  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5094  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5095  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5096  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5097  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5098  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5099  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
# 5100  Saint Petersburg, Saint Petersburg, Russia      7,326  Open Weight
#
#                                                 Details             Judge1  \
# 0                                Kick to Head On Ground                NaN
# 1                         to    \n      Corner Stoppage                NaN
# 2                       Other  \n      Position - Mount                NaN
# 3                                  Heel Hook From Guard                NaN
# 4                         to    \n      Corner Stoppage                NaN
# 5                                      Rear Naked Choke                NaN
# 6                                      Rear Naked Choke                NaN
# 7                                      Rear Naked Choke                NaN
# 8                           Guillotine Choke From Mount                NaN
# 9                             Guillotine Choke Standing                NaN
# 10    Punches to Head From Guard\n      Submission t...                NaN
# 11                              Keylock From Half Guard                NaN
# 12                        to    \n      Corner Stoppage                NaN
# 13    Other - Choke From Side Control\n      Ezekiel...                NaN
# 14                            Triangle Choke From Mount                NaN
# 15                                     Armbar On Ground                NaN
# 16                            Elbows to Head From Mount                NaN
# 17    Other - Choke From Side Control\n      Side Choke                NaN
# 18                     Elbows to Head From Side Control                NaN
# 19                                    Armbar From Mount                NaN
# 20                            Guillotine Choke Standing                NaN
# 21                           Gi Choke From Back Control                NaN
# 22    Punches to Head From Mount\n      Submission t...                NaN
# 23                            Punches to Head On Ground                NaN
# 24    Punches to Head From Half Guard\n      Submiss...                NaN
# 25                            Punches to Head In Clinch                NaN
# 26                             Armbar From Bottom Guard                NaN
# 27                                     Rear Naked Choke                NaN
# 28    Punches to Head From Mount\n      Submission t...                NaN
# 29                                               Armbar                NaN
# ...                                                 ...                ...
# 5071                                                NaN       David Brogan
# 5072                   Triangle Choke From Bottom Guard                NaN
# 5073                                                NaN   Wilfredo Cintron
# 5074                          Punch to Head At Distance                NaN
# 5075                         Guillotine Choke On Ground                NaN
# 5076                          Punch to Head At Distance                NaN
# 5077                                   Rear Naked Choke                NaN
# 5078                                                NaN        Sal D'amato
# 5079                                                NaN        Will Fisher
# 5080                                                NaN        Sal D'amato
# 5081                          Punch to Head At Distance                NaN
# 5082                                                NaN       Michael Bell
# 5083                          Punch to Head At Distance                NaN
# 5084                                                NaN       Derek Cleary
# 5085                                   Rear Naked Choke                NaN
# 5086                                                NaN       Derek Cleary
# 5087                                                NaN        Sal D'amato
# 5088                                                NaN         Ken Coffey
# 5089                                                NaN       Derek Cleary
# 5090                            Spinning Back Kick Head                NaN
# 5091                          Punch to Head At Distance                NaN
# 5092                        Punches to Head At Distance                NaN
# 5093  Other - Choke On Ground\n      Schultz front h...                NaN
# 5094                                                NaN      Howard Hughes
# 5095                                                NaN      Howard Hughes
# 5096                                                NaN  Maciej Motylewski
# 5097                                                NaN      Howard Hughes
# 5098                        Punches to Head At Distance                NaN
# 5099                                                NaN     David Letherby
# 5100                             Knee to Head In Clinch                NaN
#
#       ... Fighter2_Sig_Strikes_Head_Attempted_Round5  \
# 0     ...                                        NaN
# 1     ...                                        NaN
# 2     ...                                        NaN
# 3     ...                                        NaN
# 4     ...                                        NaN
# 5     ...                                        NaN
# 6     ...                                        NaN
# 7     ...                                        NaN
# 8     ...                                        NaN
# 9     ...                                        NaN
# 10    ...                                        NaN
# 11    ...                                        NaN
# 12    ...                                        NaN
# 13    ...                                        NaN
# 14    ...                                        NaN
# 15    ...                                        NaN
# 16    ...                                        NaN
# 17    ...                                        NaN
# 18    ...                                        NaN
# 19    ...                                        NaN
# 20    ...                                        NaN
# 21    ...                                        NaN
# 22    ...                                        NaN
# 23    ...                                        NaN
# 24    ...                                        NaN
# 25    ...                                        NaN
# 26    ...                                        NaN
# 27    ...                                        NaN
# 28    ...                                        NaN
# 29    ...                                        NaN
# ...   ...                                        ...
# 5071  ...                                        NaN
# 5072  ...                                        NaN
# 5073  ...                                        NaN
# 5074  ...                                        NaN
# 5075  ...                                        NaN
# 5076  ...                                        NaN
# 5077  ...                                        NaN
# 5078  ...                                        NaN
# 5079  ...                                        NaN
# 5080  ...                                        NaN
# 5081  ...                                        NaN
# 5082  ...                                        NaN
# 5083  ...                                        NaN
# 5084  ...                                        NaN
# 5085  ...                                        NaN
# 5086  ...                                        NaN
# 5087  ...                                        NaN
# 5088  ...                                         49
# 5089  ...                                         55
# 5090  ...                                        NaN
# 5091  ...                                        NaN
# 5092  ...                                        NaN
# 5093  ...                                        NaN
# 5094  ...                                        NaN
# 5095  ...                                        NaN
# 5096  ...                                        NaN
# 5097  ...                                        NaN
# 5098  ...                                        NaN
# 5099  ...                                        NaN
# 5100  ...                                        NaN
#
#      Fighter2_Sig_Strikes_Head_Round5  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ...                               ...
# 5071                              NaN
# 5072                              NaN
# 5073                              NaN
# 5074                              NaN
# 5075                              NaN
# 5076                              NaN
# 5077                              NaN
# 5078                              NaN
# 5079                              NaN
# 5080                              NaN
# 5081                              NaN
# 5082                              NaN
# 5083                              NaN
# 5084                              NaN
# 5085                              NaN
# 5086                              NaN
# 5087                              NaN
# 5088                               32
# 5089                               22
# 5090                              NaN
# 5091                              NaN
# 5092                              NaN
# 5093                              NaN
# 5094                              NaN
# 5095                              NaN
# 5096                              NaN
# 5097                              NaN
# 5098                              NaN
# 5099                              NaN
# 5100                              NaN
#
#      Fighter2_Sig_Strikes_Leg_Attempted_Round5  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ...                                        ...
# 5071                                       NaN
# 5072                                       NaN
# 5073                                       NaN
# 5074                                       NaN
# 5075                                       NaN
# 5076                                       NaN
# 5077                                       NaN
# 5078                                       NaN
# 5079                                       NaN
# 5080                                       NaN
# 5081                                       NaN
# 5082                                       NaN
# 5083                                       NaN
# 5084                                       NaN
# 5085                                       NaN
# 5086                                       NaN
# 5087                                       NaN
# 5088                                         7
# 5089                                         1
# 5090                                       NaN
# 5091                                       NaN
# 5092                                       NaN
# 5093                                       NaN
# 5094                                       NaN
# 5095                                       NaN
# 5096                                       NaN
# 5097                                       NaN
# 5098                                       NaN
# 5099                                       NaN
# 5100                                       NaN
#
#      Fighter2_Sig_Strikes_Leg_Round5 Fighter2_Sig_Strikes_Round5  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# 5                                NaN                         NaN
# 6                                NaN                         NaN
# 7                                NaN                         NaN
# 8                                NaN                         NaN
# 9                                NaN                         NaN
# 10                               NaN                         NaN
# 11                               NaN                         NaN
# 12                               NaN                         NaN
# 13                               NaN                         NaN
# 14                               NaN                         NaN
# 15                               NaN                         NaN
# 16                               NaN                         NaN
# 17                               NaN                         NaN
# 18                               NaN                         NaN
# 19                               NaN                         NaN
# 20                               NaN                         NaN
# 21                               NaN                         NaN
# 22                               NaN                         NaN
# 23                               NaN                         NaN
# 24                               NaN                         NaN
# 25                               NaN                         NaN
# 26                               NaN                         NaN
# 27                               NaN                         NaN
# 28                               NaN                         NaN
# 29                               NaN                         NaN
# ...                              ...                         ...
# 5071                             NaN                         NaN
# 5072                             NaN                         NaN
# 5073                             NaN                         NaN
# 5074                             NaN                         NaN
# 5075                             NaN                         NaN
# 5076                             NaN                         NaN
# 5077                             NaN                         NaN
# 5078                             NaN                         NaN
# 5079                             NaN                         NaN
# 5080                             NaN                         NaN
# 5081                             NaN                         NaN
# 5082                             NaN                         NaN
# 5083                             NaN                         NaN
# 5084                             NaN                         NaN
# 5085                             NaN                         NaN
# 5086                             NaN                         NaN
# 5087                             NaN                         NaN
# 5088                               4                          37
# 5089                               1                          26
# 5090                             NaN                         NaN
# 5091                             NaN                         NaN
# 5092                             NaN                         NaN
# 5093                             NaN                         NaN
# 5094                             NaN                         NaN
# 5095                             NaN                         NaN
# 5096                             NaN                         NaN
# 5097                             NaN                         NaN
# 5098                             NaN                         NaN
# 5099                             NaN                         NaN
# 5100                             NaN                         NaN
#
#      Fighter2_Submission_Attempts_Round5 Fighter2_Take_Downs_Attempted_Round5  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# 5                                    NaN                                  NaN
# 6                                    NaN                                  NaN
# 7                                    NaN                                  NaN
# 8                                    NaN                                  NaN
# 9                                    NaN                                  NaN
# 10                                   NaN                                  NaN
# 11                                   NaN                                  NaN
# 12                                   NaN                                  NaN
# 13                                   NaN                                  NaN
# 14                                   NaN                                  NaN
# 15                                   NaN                                  NaN
# 16                                   NaN                                  NaN
# 17                                   NaN                                  NaN
# 18                                   NaN                                  NaN
# 19                                   NaN                                  NaN
# 20                                   NaN                                  NaN
# 21                                   NaN                                  NaN
# 22                                   NaN                                  NaN
# 23                                   NaN                                  NaN
# 24                                   NaN                                  NaN
# 25                                   NaN                                  NaN
# 26                                   NaN                                  NaN
# 27                                   NaN                                  NaN
# 28                                   NaN                                  NaN
# 29                                   NaN                                  NaN
# ...                                  ...                                  ...
# 5071                                 NaN                                  NaN
# 5072                                 NaN                                  NaN
# 5073                                 NaN                                  NaN
# 5074                                 NaN                                  NaN
# 5075                                 NaN                                  NaN
# 5076                                 NaN                                  NaN
# 5077                                 NaN                                  NaN
# 5078                                 NaN                                  NaN
# 5079                                 NaN                                  NaN
# 5080                                 NaN                                  NaN
# 5081                                 NaN                                  NaN
# 5082                                 NaN                                  NaN
# 5083                                 NaN                                  NaN
# 5084                                 NaN                                  NaN
# 5085                                 NaN                                  NaN
# 5086                                 NaN                                  NaN
# 5087                                 NaN                                  NaN
# 5088                                   2                                    0
# 5089                                   0                                    0
# 5090                                 NaN                                  NaN
# 5091                                 NaN                                  NaN
# 5092                                 NaN                                  NaN
# 5093                                 NaN                                  NaN
# 5094                                 NaN                                  NaN
# 5095                                 NaN                                  NaN
# 5096                                 NaN                                  NaN
# 5097                                 NaN                                  NaN
# 5098                                 NaN                                  NaN
# 5099                                 NaN                                  NaN
# 5100                                 NaN                                  NaN
#
#      Fighter2_Take_Downs_Round5 Fighter2_Total_Strikes_Attempted_Round5  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# 5                           NaN                                     NaN
# 6                           NaN                                     NaN
# 7                           NaN                                     NaN
# 8                           NaN                                     NaN
# 9                           NaN                                     NaN
# 10                          NaN                                     NaN
# 11                          NaN                                     NaN
# 12                          NaN                                     NaN
# 13                          NaN                                     NaN
# 14                          NaN                                     NaN
# 15                          NaN                                     NaN
# 16                          NaN                                     NaN
# 17                          NaN                                     NaN
# 18                          NaN                                     NaN
# 19                          NaN                                     NaN
# 20                          NaN                                     NaN
# 21                          NaN                                     NaN
# 22                          NaN                                     NaN
# 23                          NaN                                     NaN
# 24                          NaN                                     NaN
# 25                          NaN                                     NaN
# 26                          NaN                                     NaN
# 27                          NaN                                     NaN
# 28                          NaN                                     NaN
# 29                          NaN                                     NaN
# ...                         ...                                     ...
# 5071                        NaN                                     NaN
# 5072                        NaN                                     NaN
# 5073                        NaN                                     NaN
# 5074                        NaN                                     NaN
# 5075                        NaN                                     NaN
# 5076                        NaN                                     NaN
# 5077                        NaN                                     NaN
# 5078                        NaN                                     NaN
# 5079                        NaN                                     NaN
# 5080                        NaN                                     NaN
# 5081                        NaN                                     NaN
# 5082                        NaN                                     NaN
# 5083                        NaN                                     NaN
# 5084                        NaN                                     NaN
# 5085                        NaN                                     NaN
# 5086                        NaN                                     NaN
# 5087                        NaN                                     NaN
# 5088                          0                                      63
# 5089                          0                                      60
# 5090                        NaN                                     NaN
# 5091                        NaN                                     NaN
# 5092                        NaN                                     NaN
# 5093                        NaN                                     NaN
# 5094                        NaN                                     NaN
# 5095                        NaN                                     NaN
# 5096                        NaN                                     NaN
# 5097                        NaN                                     NaN
# 5098                        NaN                                     NaN
# 5099                        NaN                                     NaN
# 5100                        NaN                                     NaN
#
#      Fighter2_Total_Strikes_Round5
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# ...                            ...
# 5071                           NaN
# 5072                           NaN
# 5073                           NaN
# 5074                           NaN
# 5075                           NaN
# 5076                           NaN
# 5077                           NaN
# 5078                           NaN
# 5079                           NaN
# 5080                           NaN
# 5081                           NaN
# 5082                           NaN
# 5083                           NaN
# 5084                           NaN
# 5085                           NaN
# 5086                           NaN
# 5087                           NaN
# 5088                            43
# 5089                            26
# 5090                           NaN
# 5091                           NaN
# 5092                           NaN
# 5093                           NaN
# 5094                           NaN
# 5095                           NaN
# 5096                           NaN
# 5097                           NaN
# 5098                           NaN
# 5099                           NaN
# 5100                           NaN
#
# [5101 rows x 233 columns]
